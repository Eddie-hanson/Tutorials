# %%
#importing numpy
import numpy as np
from cProfile import label
#importing pandas
import pandas as pd
#importing seaborn
import seaborn as sns
# importing matplotlib
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
from numpy.random import rand


RandNmber=np.random.rand(10)
RandNmber
# Out:
# array([0.74372233, 0.81613991, 0.37870934, 0.25362766, 0.69370015,
#        0.20195083, 0.84574458, 0.90877896, 0.11031934, 0.98900003])

# %%
#style of the plot



style.use('ggplot')
#pllot the random number
plt.plot(RandNmber, 'g',label='line one', linewidth =2)
#x-axis 
plt.xlabel('Range')
#y-axis
plt.ylabel('Number')
#title
plt.title('My Plot')
# Out:
# Text(0.5, 1.0, 'My Plot')

# %% [markdown]
# # 2D PLOTS

# %%
Users=[123,654,67,883,56,126,43,54,245,66]
Time=[3,6,4,8,14,45,3,28,36,52]
len(Users)
# Out:
# 10

# %%
#style of the plot



style.use('ggplot')
#pllot the random number
plt.plot(Time,Users, 'g',label='line one', linewidth =2, color= 'c', linestyle='--')
#x-axis 
plt.xlabel('Users')
#y-axis
plt.ylabel('Time')
#title
plt.title('My Plot')
# Out:
# C:\Users\hans1\AppData\Local\Temp\ipykernel_16644\1735754321.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "g" (-> color=(0.0, 0.5, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(Time,Users, 'g',label='line one', linewidth =2, color= 'c', linestyle='--')
# Text(0.5, 1.0, 'My Plot')

# %%
Monday=[123,654,67,883,56,126,43,54,245,66]
Tuesday=[13,64,367,183,256,526,243,104,205,166]
Wednesday=[23,254,367,83,516,170,434,514,24,166]
Thursday=[223,354,467,283,556,226,143,254,255,366]
Friday=[623,351,401,88,206,109,143,541,45,616]

Time=[3,6,4,8,14,45,3,28,36,52]

# %%
style.use('ggplot')
#plot the random number
plt.plot(Time,Monday, 'g',label=' Monday', linewidth =2, color= 'g', linestyle='solid')
plt.plot(Time,Tuesday, 'g',label='line one', linewidth =2, color= 'k', linestyle='--',)
plt.plot(Time,Wednesday, 'g',label='line one', linewidth =2, color= 'c', linestyle=':')
plt.plot(Time,Thursday, 'g',label='line one', linewidth =2, color= 'm', linestyle='dashed')
plt.plot(Time,Friday, 'g',label='line label', linewidth =2, color= 'r', linestyle='dotted')

#x-axis 
plt.xlabel('Users')
#y-axis
plt.ylabel('Time')
#title
plt.title('My Plot')
# Out:
# C:\Users\hans1\AppData\Local\Temp\ipykernel_16644\4267037551.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "g" (-> color=(0.0, 0.5, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(Time,Monday, 'g',label=' Monday', linewidth =2, color= 'g', linestyle='solid')
# C:\Users\hans1\AppData\Local\Temp\ipykernel_16644\4267037551.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "g" (-> color=(0.0, 0.5, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(Time,Tuesday, 'g',label='line one', linewidth =2, color= 'k', linestyle='--',)
# C:\Users\hans1\AppData\Local\Temp\ipykernel_16644\4267037551.py:5: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "g" (-> color=(0.0, 0.5, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(Time,Wednesday, 'g',label='line one', linewidth =2, color= 'c', linestyle=':')
# ...

# %%
ab=pd.read_csv('Proccessed_Data.CSV')

# %%
# Load dataset
ab
# Out:
#                                                  title  \
# 0                 I Got Hunted By A Real Bounty Hunter
# 1                     Extreme $1,000,000 Hide And Seek
# 2    I Bought The World&#39;s Largest Mystery Box! ...
# 3                      First To Rob Bank Wins $100,000
# 4                   Press This Button To Win $100,000!
# ..                                                 ...
# 239                         Remember When COD Was Fun?
# 240                  Insane Gun Sync - 7 Hours To Make
# 241   MY MESSAGE TO COD YOUTUBERS (Watch till end plz)
# 242    L0114R - Biblical Creeper Post for Post @L0114R
# 243  How Much Money Do You Make As An Uber Driver??...
#
#                                            description  \
# 0    Sign up for Current w/ my Creator Code "BEAST"...
# 1    I didn't expect that to happen at the end I wa...
# 2    I cant believe I spent over $500000 on mystery...
# 3    I didnt think he would actually rob the bank.....
# ...

# %%
# plot the histogram
ab.plot(kind='hist', x='likeCount', y='viewCount', title='View to Like' ,figsize=(15,10))
# Out:
# <Axes: title={'center': 'View to Like'}, ylabel='Frequency'>

# %%
ab.plot(kind='scatter', x='likeCount', y='viewCount', title='View to Like' ,figsize=(15,10))
# Out:
# <Axes: title={'center': 'View to Like'}, xlabel='likeCount', ylabel='viewCount'>

# %%
#Heat Maps
ab.head()
# Out:
#                                                title  \
# 0               I Got Hunted By A Real Bounty Hunter
# 1                   Extreme $1,000,000 Hide And Seek
# 2  I Bought The World&#39;s Largest Mystery Box! ...
# 3                    First To Rob Bank Wins $100,000
# 4                 Press This Button To Win $100,000!
#
#                                          description  \
# 0  Sign up for Current w/ my Creator Code "BEAST"...
# 1  I didn't expect that to happen at the end I wa...
# 2  I cant believe I spent over $500000 on mystery...
# 3  I didnt think he would actually rob the bank.....
# 4  Push the red subscribe button and you could al...
#
#                  publishTime  duration_seconds  viewCount  likeCount  \
# 0  2021-04-24 20:00:00+00:00               861   84717282    2876493
# 1  2021-12-18 21:00:00+00:00               729   32090178    2125183
# 2  2021-04-03 20:00:01+00:00               709  101745632    3110824
# ...

# %% [markdown]
# ## HEAT MAPS

# %%
ab1=ab[['duration_seconds','viewCount','likeCount','commentCount','Like_To_View_Ratio']]

# %%
sns.heatmap(ab1)
# Out:
# <Axes: >

# %%
ab1.plot.pie(y='likeCount')
# Out:
# <Axes: ylabel='likeCount'>

# %%
ab2=ab1.loc[12:40]
ab2
# Out:
#     duration_seconds  viewCount  likeCount  commentCount  Like_To_View_Ratio
# 12               725   34223993    2280759       80603.0            0.066642
# 13               662   43165039    2416595       90170.0            0.055985
# 14               694   55202068    2004164       78869.0            0.036306
# 15              1014   84989496    2449214      121200.0            0.028818
# 16               802   90623591    1883897       65304.0            0.020788
# 17               483   99174289    2642315      125468.0            0.026643
# 18               843  103902204    2471218       92745.0            0.023784
# 19               694   85113492    2833891      187948.0            0.033295
# 20              1166   95809336    3482783       94926.0            0.036351
# 21               669  106594059    3641646      169970.0            0.034164
# 22               964  104797858    3343738      190567.0            0.031907
# ...

# %%
ab2.plot.pie(y='duration_seconds')
# Out:
# <Axes: ylabel='duration_seconds'>
