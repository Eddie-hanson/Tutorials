# %%
import pandas as pd
import chart_studio.plotly as py
import matplotlib.pyplot as plt
import cufflinks as cufflinks
from plotly.offline import iplot, plot, init_notebook_mode, download_plotlyjs
import numpy as np
import plotly.graph_objs as go

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.30.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df= pd.read_csv('2011_us_ag_exports.csv')

# %%
df
# Out:
#    code           state category  total exports   beef    pork  poultry  \
# 0    AL         Alabama    state        1390.63   34.4    10.6    481.0
# 1    AK          Alaska    state          13.31    0.2     0.1      0.0
# 2    AZ         Arizona    state        1463.17   71.3    17.9      0.0
# 3    AR        Arkansas    state        3586.02   53.2    29.4    562.9
# 4    CA      California    state       16472.88  228.7    11.1    225.4
# 5    CO        Colorado    state        1851.33  261.4    66.0     14.0
# 6    CT     Connecticut    state         259.62    1.1     0.1      6.9
# 7    DE        Delaware    state         282.19    0.4     0.6    114.7
# 8    FL         Florida    state        3764.09   42.6     0.9     56.9
# 9    GA         Georgia    state        2860.84   31.0    18.9    630.4
# 10   HI          Hawaii    state         401.84    4.0     0.7      1.3
# 11   ID           Idaho    state        2078.89  119.8     0.0      2.4
# ...

# %%
df.size
# Out:
# 850

# %%
df.dtypes
# Out:
# code              object
# state             object
# category          object
# total exports    float64
# beef             float64
# pork             float64
# poultry          float64
# dairy            float64
# fruits fresh     float64
# fruits proc      float64
# total fruits     float64
# veggies fresh    float64
# veggies proc     float64
# total veggies    float64
# corn             float64
# wheat            float64
# cotton           float64
# dtype: object

# %%
df.describe()
# Out:
#        total exports        beef         pork     poultry       dairy  \
# count      50.000000   50.000000    50.000000   50.000000   50.000000
# mean     2728.889000  108.394000   122.282000  112.700000   95.725200
# std      3144.837608  193.762904   303.492907  162.878644  168.016886
# min        13.310000    0.100000     0.000000    0.000000    0.190000
# 25%       465.142500   13.400000     0.525000    2.950000    6.980000
# 50%      1822.950000   41.050000    16.800000   33.550000   32.165000
# 75%      3768.665000  106.725000    84.975000  162.425000  101.535000
# max     16472.880000  961.000000  1895.600000  630.400000  929.950000
#
#        fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# count      50.00000    50.000000      50.00000      50.000000     50.000000
# mean       90.05000   191.736000     281.79000      44.428000     72.102000
# std       402.16488   856.334256    1258.49891     116.513625    189.088833
# ...

# %%
df['total exports'].describe()
# Out:
# count       50.000000
# mean      2728.889000
# std       3144.837608
# min         13.310000
# 25%        465.142500
# 50%       1822.950000
# 75%       3768.665000
# max      16472.880000
# Name: total exports, dtype: float64

# %%
df.columns
# Out:
# Index(['code', 'state', 'category', 'total exports', 'beef', 'pork', 'poultry',
#        'dairy', 'fruits fresh', 'fruits proc', 'total fruits', 'veggies fresh',
#        'veggies proc', 'total veggies', 'corn', 'wheat', 'cotton'],
#       dtype='object')

# %% [markdown]
# ## SUBSETTING DATA

# %% [markdown]
# #### AnimalProduct

# %%
AnimalProduct=df[['code', 'state', 'category','beef', 'pork', 'poultry',
       'dairy', ]]

# %%
AnimalProduct
# Out:
#    code           state category   beef    pork  poultry   dairy
# 0    AL         Alabama    state   34.4    10.6    481.0    4.06
# 1    AK          Alaska    state    0.2     0.1      0.0    0.19
# 2    AZ         Arizona    state   71.3    17.9      0.0  105.48
# 3    AR        Arkansas    state   53.2    29.4    562.9    3.53
# 4    CA      California    state  228.7    11.1    225.4  929.95
# 5    CO        Colorado    state  261.4    66.0     14.0   71.94
# 6    CT     Connecticut    state    1.1     0.1      6.9    9.49
# 7    DE        Delaware    state    0.4     0.6    114.7    2.30
# 8    FL         Florida    state   42.6     0.9     56.9   66.31
# 9    GA         Georgia    state   31.0    18.9    630.4   38.38
# 10   HI          Hawaii    state    4.0     0.7      1.3    1.16
# 11   ID           Idaho    state  119.8     0.0      2.4  294.60
# 12   IL        Illinois    state   53.7   394.0     14.0   45.82
# ...

# %%
AnimalProduct['Total Animal Export']=AnimalProduct['beef']+AnimalProduct['pork']+AnimalProduct['poultry']+AnimalProduct['dairy']

# %%
AnimalProduct
# Out:
#    code           state category   beef    pork  poultry   dairy  \
# 0    AL         Alabama    state   34.4    10.6    481.0    4.06
# 1    AK          Alaska    state    0.2     0.1      0.0    0.19
# 2    AZ         Arizona    state   71.3    17.9      0.0  105.48
# 3    AR        Arkansas    state   53.2    29.4    562.9    3.53
# 4    CA      California    state  228.7    11.1    225.4  929.95
# 5    CO        Colorado    state  261.4    66.0     14.0   71.94
# 6    CT     Connecticut    state    1.1     0.1      6.9    9.49
# 7    DE        Delaware    state    0.4     0.6    114.7    2.30
# 8    FL         Florida    state   42.6     0.9     56.9   66.31
# 9    GA         Georgia    state   31.0    18.9    630.4   38.38
# 10   HI          Hawaii    state    4.0     0.7      1.3    1.16
# 11   ID           Idaho    state  119.8     0.0      2.4  294.60
# 12   IL        Illinois    state   53.7   394.0     14.0   45.82
# ...

# %% [markdown]
# #### Farm Produce

# %%
FarmProduce=df[['code', 'state', 'category','fruits fresh', 'fruits proc', 'total fruits', 'veggies fresh','veggies proc', 'total veggies', 'corn', 'wheat', 'cotton']]

# %%
FarmProduce
# Out:
#    code           state category  fruits fresh  fruits proc  total fruits  \
# 0    AL         Alabama    state           8.0         17.1         25.11
# 1    AK          Alaska    state           0.0          0.0          0.00
# 2    AZ         Arizona    state          19.3         41.0         60.27
# 3    AR        Arkansas    state           2.2          4.7          6.88
# 4    CA      California    state        2791.8       5944.6       8736.40
# 5    CO        Colorado    state           5.7         12.2         17.99
# 6    CT     Connecticut    state           4.2          8.9         13.10
# 7    DE        Delaware    state           0.5          1.0          1.53
# 8    FL         Florida    state         438.2        933.1       1371.36
# 9    GA         Georgia    state          74.6        158.9        233.51
# 10   HI          Hawaii    state          17.7         37.8         55.51
# 11   ID           Idaho    state           6.9         14.7         21.64
# ...

# %%
FarmProduce.columns
# Out:
# Index(['code', 'state', 'category', 'fruits fresh', 'fruits proc',
#        'total fruits', 'veggies fresh', 'veggies proc', 'total veggies',
#        'corn', 'wheat', 'cotton'],
#       dtype='object')

# %%
FarmProduce['Total Farm Produce']=FarmProduce['total fruits']+FarmProduce['total veggies']+FarmProduce['corn']+FarmProduce['wheat']+FarmProduce['cotton']

# %%
FarmProduce
# Out:
#    code           state category  fruits fresh  fruits proc  total fruits  \
# 0    AL         Alabama    state           8.0         17.1         25.11
# 1    AK          Alaska    state           0.0          0.0          0.00
# 2    AZ         Arizona    state          19.3         41.0         60.27
# 3    AR        Arkansas    state           2.2          4.7          6.88
# 4    CA      California    state        2791.8       5944.6       8736.40
# 5    CO        Colorado    state           5.7         12.2         17.99
# 6    CT     Connecticut    state           4.2          8.9         13.10
# 7    DE        Delaware    state           0.5          1.0          1.53
# 8    FL         Florida    state         438.2        933.1       1371.36
# 9    GA         Georgia    state          74.6        158.9        233.51
# 10   HI          Hawaii    state          17.7         37.8         55.51
# 11   ID           Idaho    state           6.9         14.7         21.64
# ...

# %% [markdown]
# ##### Subsetting fruit produce

# %%
Fruits=df[['code', 'state', 'category','fruits fresh', 'fruits proc', 'total fruits']]

# %%
Crops=df[['code', 'state', 'category','corn', 'wheat', 'cotton']]

# %%
Vegetables=df[['code', 'state', 'category','veggies fresh',
       'veggies proc', 'total veggies']]

# %%
Fruits
# Out:
#    code           state category  fruits fresh  fruits proc  total fruits
# 0    AL         Alabama    state           8.0         17.1         25.11
# 1    AK          Alaska    state           0.0          0.0          0.00
# 2    AZ         Arizona    state          19.3         41.0         60.27
# 3    AR        Arkansas    state           2.2          4.7          6.88
# 4    CA      California    state        2791.8       5944.6       8736.40
# 5    CO        Colorado    state           5.7         12.2         17.99
# 6    CT     Connecticut    state           4.2          8.9         13.10
# 7    DE        Delaware    state           0.5          1.0          1.53
# 8    FL         Florida    state         438.2        933.1       1371.36
# 9    GA         Georgia    state          74.6        158.9        233.51
# 10   HI          Hawaii    state          17.7         37.8         55.51
# 11   ID           Idaho    state           6.9         14.7         21.64
# ...

# %%
 Crops['Total Crops']=Crops['corn']+Crops['wheat']+Crops['cotton']

# %%
Crops
# Out:
#    code           state category    corn   wheat   cotton  Total Crops
# 0    AL         Alabama    state    34.9    70.0   317.61       422.51
# 1    AK          Alaska    state     0.0     0.0     0.00         0.00
# 2    AZ         Arizona    state     7.3    48.7   423.95       479.95
# 3    AR        Arkansas    state    69.5   114.5   665.44       849.44
# 4    CA      California    state    34.6   249.3  1064.95      1348.85
# 5    CO        Colorado    state   183.2   400.5     0.00       583.70
# 6    CT     Connecticut    state     0.0     0.0     0.00         0.00
# 7    DE        Delaware    state    26.9    22.9     0.00        49.80
# 8    FL         Florida    state     3.5     1.8    78.24        83.54
# 9    GA         Georgia    state    57.8    65.4  1154.07      1277.27
# 10   HI          Hawaii    state     0.0     0.0     0.00         0.00
# 11   ID           Idaho    state    24.0   568.2     0.00       592.20
# ...

# %%
Vegetables
# Out:
#    code           state category  veggies fresh  veggies proc  total veggies
# 0    AL         Alabama    state            5.5           8.9          14.33
# 1    AK          Alaska    state            0.6           1.0           1.56
# 2    AZ         Arizona    state          147.5         239.4         386.91
# 3    AR        Arkansas    state            4.4           7.1          11.45
# 4    CA      California    state          803.2        1303.5        2106.79
# 5    CO        Colorado    state           45.1          73.2         118.27
# 6    CT     Connecticut    state            4.3           6.9          11.16
# 7    DE        Delaware    state            7.6          12.4          20.03
# 8    FL         Florida    state          171.9         279.0         450.86
# 9    GA         Georgia    state           59.0          95.8         154.77
# 10   HI          Hawaii    state            9.5          15.4          24.83
# ...

# %% [markdown]
# ## Plots

# %%
df.columns
# Out:
# Index(['code', 'state', 'category', 'total exports', 'beef', 'pork', 'poultry',
#        'dairy', 'fruits fresh', 'fruits proc', 'total fruits', 'veggies fresh',
#        'veggies proc', 'total veggies', 'corn', 'wheat', 'cotton'],
#       dtype='object')

# %%
df_Data=dict(type='choropleth', colorscale='spectral',locations=df['code'], locationmode='USA-states',z=df['total exports'], text=df['state'], colorbar={'title':'Million USD'},marker=dict(line=dict(color='#FF0088', width=1)),)

# %%
layout=dict(title='2011 Agricultural Export By US States', geo=dict(scope='usa'))

# %%
Df_Map=go.Figure(data=[df_Data], layout=layout)

# %%
iplot(Df_Map)
# Out:
# <div>                            <div id="0e3aa3f1-261d-4fdd-b924-ad89b719ff56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e3aa3f1-261d-4fdd-b924-ad89b719ff56")) {                    Plotly.newPlot(                        "0e3aa3f1-261d-4fdd-b924-ad89b719ff56",                        [{"colorbar":{"title":{"text":"Million USD"}},"colorscale":[[0.0,"rgb(158,1,66)"],[0.1,"rgb(213,62,79)"],[0.2,"rgb(244,109,67)"],[0.3,"rgb(253,174,97)"],[0.4,"rgb(254,224,139)"],[0.5,"rgb(255,255,191)"],[0.6,"rgb(230,245,152)"],[0.7,"rgb(171,221,164)"],[0.8,"rgb(102,194,165)"],[0.9,"rgb(50,136,189)"],[1.0,"rgb(94,79,162)"]],"locationmode":"USA-states","locations":["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","
# ...

# %%
df1=df[['beef', 'pork']]
