# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df1.shape
# Out:
# (1000, 4)

# %%
df2=pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
df1['A'].plot(kind='hist', figsize= (20,10), bins=30)
plt.grid(True)

# %%
df2['a'].plot.hist( figsize= (15,10), bins=20)
plt.grid(True)

# %%
''''Alpha for transparency 0 >=1
'''
df2.plot.area(alpha=0.9)
# Out:
# <Axes: >

# %%
''''"Bar plot, to stack the bar graph pass in the arguement "stacked=True"
'''

df2.plot.bar(title = 'Not Stacked', figsize=(10,5)) , df2.plot.bar(stacked=True, title='Stacked' ,figsize=(12,5))
# Out:
# (<Axes: title={'center': 'Not Stacked'}>, <Axes: title={'center': 'Stacked'}>)

# %%
df1['A'].plot.hist(grid=True, bins=30, figsize=(12,7))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.line(y='B', figsize=(15,10), color='green', lw=2, marker='*', markersize=5, markerfacecolor='red')
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='A',y='B', c='C',cmap='coolwarm')
plt.grid=True

# %%
'''s '''
df1.plot.scatter(x='A',y='B', s=df1['C']*90)
# Out:
# c:\Users\hans1\miniconda3\envs\CondaEnv\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>
# c:\Users\hans1\miniconda3\envs\CondaEnv\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>
# Error in callback <function flush_figures at 0x0000019AC7206F20> (for post_execute), with arguments args (),kwargs {}:

# %% [markdown]
# # BOX PLOT

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df=pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])

# %%
df
# Out:
#             a         b
# 0   -1.228627 -1.427410
# 1    0.163020 -0.237079
# 2    1.003380 -0.589690
# 3   -0.692035  0.045597
# 4    1.253442  0.047196
# ..        ...       ...
# 995 -0.311095 -0.095149
# 996  0.296667 -1.123729
# 997  0.464109 -1.462993
# 998 -1.674259 -1.468182
# 999  0.649466 -1.170952
#
# [1000 rows x 2 columns]

# %% [markdown]
# # Hexplot

# %%
'''''gridsize enlarges size of hexagon, 
cmap changes color of map some colors include ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu', 'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn','Greys',
'Purples', 'Blues', 'Greens', 'Oranges', 'Reds', 'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']]
'''
df.plot.hexbin(x='a',y='b', gridsize=30, cmap='YlGn')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# # Kernel Density Estimation plot
#  is a non-parametric way to estimate the probability density function (PDF) of a random variable. This function uses Gaussian kernels and includes automatic bandwidth determination. can be called using kde() or density()

# %%
df2['a'].plot.kde()
plt.grid=True

# %%
df1.plot.kde(figsize=(20,11))
# Out:
# <Axes: ylabel='Density'>

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df2.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
df3=pd.read_csv['df3']

# %%
df3
